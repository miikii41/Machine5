# %%
from google.colab import drive
import pandas as pd

drive.mount('/content/drive')

data = pd.read_csv('/content/drive/MyDrive/mon_features.csv')

print(data.head())
# Out:
# Mounted at /content/drive
#    label  total_num  total_sum_dir  total_avg  inpkt_num  inpkt_avg  \
# 0      0       1421        -603648   4.315749       1300   4.292023
# 1      0        518        -183296   4.611815        438   4.673242
# 2      0       1358        -574464   5.488969       1240   5.459452
# 3      0       1446        -615424   5.995512       1324   5.948693
# 4      0       1406        -602112   4.698869       1291   4.663873
#
#    inpkt_sum  inpkt_num_frac_total  inpkt_avg_ordering  inpkt_std_ordering  \
# 0    5579.63              0.914849          704.106154          398.486335
# 1    2046.88              0.845560          264.406393          150.591146
# 2    6769.72              0.913108          668.259677          381.878642
# 3    7876.07              0.915629          713.503021          406.205288
# 4    6021.06              0.918208          694.740511          395.028889
#
#    ...  outpkt_num_frac_inpkt  outpkt_sum_firstn  inpkt_std_burst  \
# 0  ...               0.093077               7.39        17.195458
# 1  ...               0.182648               9.71        12.176200
# 2  ...               0.095161               7.83        16.584084
# 3  ...               0.092145              11.53        17.252464
# 4  ...               0.089078               7.17        16.014144
#
#    inpkt_max_burst  inpkt_avg_burst  inpkt_count_burst  outpkt_std_burst  \
# 0               66        16.666667                 78          1.139584
# 1               50         9.319149                 47          1.128262
# 2               50        16.315789                 76          0.978650
# 3               70        16.550000                 80          0.851102
# 4               60        16.341772                 79          0.882996
#
#    outpkt_max_burst  outpkt_avg_burst  outpkt_count_burst
# 0                 8          1.551282                  78
# 1                 5          1.702128                  47
# 2                 6          1.552632                  76
# 3                 5          1.525000                  80
# 4                 5          1.455696                  79
#
# [5 rows x 28 columns]

# %% [markdown]
# 데이터 전처리 및 데이터 분류

# %%
X = data.drop(columns=['label'])
y = data['label']

#데이터 표준화
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# RandomForest 생성, 학습, 평가

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, log_loss, classification_report, confusion_matrix


rf_model = RandomForestClassifier(n_estimators=100, max_depth=35, random_state=42, class_weight='balanced')
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=35, random_state=42)

# %%
y_pred_rf = rf_model.predict(X_test)
y_pred_proba_rf = rf_model.predict_proba(X_test)

print("Random Forest Accuracy:", accuracy_score(y_test, y_pred_rf))
print("Random Forest Precision:", precision_score(y_test, y_pred_rf, average='weighted'))
print("Random Forest Recall:", recall_score(y_test, y_pred_rf, average='weighted'))
print("Random Forest LogLoss:", log_loss(y_test, y_pred_proba_rf))

print("Random Forest Classification Report:\n", classification_report(y_test, y_pred_rf))


rf_accuracy = accuracy_score(y_test, y_pred_rf)
print("Random Forest Accuracy:", rf_accuracy)
# Out:
# Random Forest Accuracy: 0.738421052631579
# Random Forest Precision: 0.7415569047652172
# Random Forest Recall: 0.738421052631579
# Random Forest LogLoss: 2.3942523793210477
# Random Forest Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.76      0.69      0.72        42
#            1       0.67      0.48      0.56        42
#            2       0.79      0.94      0.86        35
#            3       0.74      0.90      0.81        29
#            4       0.64      0.92      0.76        39
#            5       0.91      0.89      0.90        45
#            6       0.70      0.84      0.76        44
#            7       0.63      0.81      0.71        36
#            8       0.71      0.71      0.71        34
#            9       0.49      0.68      0.57        31
#           10       0.82      0.70      0.76        47
#           11       0.77      0.77      0.77        35
#           12       0.77      0.86      0.81        42
#           13       0.50      0.40      0.44        40
#           14       0.64      0.44      0.52        36
#           15       0.74      0.80      0.77        35
#           16       0.79      0.72      0.76        43
#           17       0.70      0.70      0.70        47
#           18       0.97      1.00      0.99        37
#           19       0.79      0.70      0.74        37
#           20       0.84      0.93      0.88        44
#           21       0.74      0.56      0.64        41
#           22       0.68      0.62      0.65        40
#           23       0.70      0.80      0.75        35
#           24       0.56      0.33      0.41        46
#           25       0.81      0.72      0.76        36
#           26       0.74      1.00      0.85        37
#           27       0.79      0.73      0.76        45
#           28       0.89      0.86      0.87        36
#           29       0.78      0.77      0.77        47
#           30       0.67      0.70      0.68        46
#           31       0.75      0.89      0.81        37
#           32       0.56      0.47      0.51        38
#           33       0.78      0.86      0.82        37
#           34       0.63      0.59      0.61        41
#           35       0.77      0.89      0.83        38
#           36       0.77      0.77      0.77        35
#           37       0.74      0.55      0.63        53
#           38       0.66      0.70      0.68        53
#           39       0.76      0.70      0.73        46
#           40       0.73      0.75      0.74        51
#           41       0.83      0.81      0.82        43
#           42       0.70      0.54      0.61        39
#           43       0.76      0.83      0.79        41
#           44       0.98      0.98      0.98        44
#           45       0.50      0.60      0.55        35
#           46       0.71      0.69      0.70        35
#           47       0.71      0.69      0.70        39
#           48       0.83      0.81      0.82        37
#           49       0.81      0.79      0.80        43
#           50       0.65      0.69      0.67        32
#           51       0.58      0.66      0.62        38
#           52       0.78      0.71      0.74        49
#           53       0.61      0.81      0.69        31
#           54       0.84      0.81      0.83        47
#           55       0.54      0.63      0.58        41
#           56       0.94      0.94      0.94        47
#           57       0.64      0.75      0.69        36
#           58       0.79      0.94      0.86        35
#           59       0.79      0.85      0.81        39
#           60       0.80      0.88      0.83        40
#           61       0.86      0.64      0.73        56
#           62       0.81      0.67      0.73        57
#           63       0.62      0.59      0.60        27
#           64       0.84      0.82      0.83        39
#           65       0.55      0.66      0.60        35
#           66       0.70      0.80      0.75        46
#           67       0.87      0.89      0.88        37
#           68       0.85      0.48      0.61        48
#           69       0.56      0.53      0.55        43
#           70       0.91      0.94      0.93        34
#           71       0.77      0.75      0.76        36
#           72       0.74      0.64      0.68        39
#           73       0.95      0.95      0.95        41
#           74       0.59      0.57      0.58        53
#           75       0.88      1.00      0.94        37
#           76       0.95      0.93      0.94        44
#           77       0.52      0.50      0.51        30
#           78       0.47      0.50      0.49        36
#           79       0.64      0.60      0.62        30
#           80       0.82      0.82      0.82        40
#           81       0.79      0.76      0.77        45
#           82       0.80      0.53      0.64        45
#           83       0.69      0.77      0.73        31
#           84       0.64      0.70      0.67        40
#           85       0.83      0.80      0.81        44
#           86       0.97      1.00      0.99        37
#           87       0.86      0.69      0.76        35
#           88       0.70      0.81      0.75        37
#           89       0.63      0.63      0.63        38
#           90       0.81      0.72      0.76        36
#           91       0.67      0.77      0.71        39
#           92       0.69      0.77      0.73        35
#           93       0.81      0.97      0.88        39
#           94       0.62      0.67      0.64        42
#
#     accuracy                           0.74      3800
#    macro avg       0.74      0.74      0.73      3800
# weighted avg       0.74      0.74      0.74      3800
#
# Random Forest Accuracy: 0.738421052631579

# %%
cm = confusion_matrix(y_test,  y_pred_rf)
print(cm)
# Out:
# [[29  0  0 ...  1  0  0]
#  [ 2 20  0 ...  0  0  0]
#  [ 0  0 33 ...  0  0  0]
#  ...
#  [ 0  0  1 ... 27  0  0]
#  [ 0  0  0 ...  0 38  0]
#  [ 0  0  0 ...  1  0 28]]
