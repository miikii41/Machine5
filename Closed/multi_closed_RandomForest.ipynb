# %%
from google.colab import drive
import pandas as pd

drive.mount('/content/drive')

data = pd.read_csv('/content/drive/MyDrive/mon_features.csv')

print(data.head())
# Out:
# Mounted at /content/drive
#    label  total_num  total_sum_dir  total_avg  inpkt_num  inpkt_avg  \
# 0      0      19000        -603648   4.315749       1300   4.292023
# 1      0      19000        -183296   4.611815        438   4.673242
# 2      0      19000        -574464   5.488969       1240   5.459452
# 3      0      19000        -615424   5.995512       1324   5.948693
# 4      0      19000        -602112   4.698869       1291   4.663873
#
#    inpkt_sum  inpkt_num_frac_total  inpkt_avg_ordering  inpkt_std_ordering  \
# 0    5579.63              0.068421          704.106154          398.486335
# 1    2046.88              0.023053          264.406393          150.591146
# 2    6769.72              0.065263          668.259677          381.878642
# 3    7876.07              0.069684          713.503021          406.205288
# 4    6021.06              0.067947          694.740511          395.028889
#
#    inpkt_num_frac_outpkt  inpkt_sum_firstn  outpkt_num  outpkt_avg  \
# 0              10.743802             16.10         121    4.570661
# 1               5.475000             27.52          80    4.275500
# 2              10.508475             28.09         118    5.799153
# 3              10.852459             25.24         122    6.503607
# 4              11.226087             19.71         115    5.091739
#
#    outpkt_sum  outpkt_num_frac_total  outpkt_avg_ordering  \
# 0     5579.63               0.006368           773.322314
# 1     2046.88               0.004211           226.162500
# 2     6769.72               0.006211           786.110169
# 3     7876.07               0.006421           820.139344
# 4     6021.06               0.006053           789.608696
#
#    outpkt_std_ordering  outpkt_num_frac_inpkt  outpkt_sum_firstn
# 0           515.483953               0.093077               7.39
# 1           139.231951               0.182648               9.71
# 2           472.735508               0.095161               7.83
# 3           513.916038               0.092145              11.53
# 4           503.993490               0.089078               7.17

# %% [markdown]
# 데이터 전처리 및 데이터 분류

# %%
X = data.drop(columns=['label'])
y = data['label']

#데이터 표준화
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size=0.2, random_state=42)

# %% [markdown]
# RandomForest 생성, 학습, 평가

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, log_loss, classification_report, confusion_matrix


rf_model = RandomForestClassifier(n_estimators=100, max_depth=35, random_state=42, class_weight='balanced')
rf_model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=35, random_state=42)

# %%
y_pred_rf = rf_model.predict(X_test)
y_pred_proba_rf = rf_model.predict_proba(X_test)

print("Random Forest Accuracy:", accuracy_score(y_test, y_pred_rf))
print("Random Forest Precision:", precision_score(y_test, y_pred_rf, average='weighted'))
print("Random Forest Recall:", recall_score(y_test, y_pred_rf, average='weighted'))
print("Random Forest LogLoss:", log_loss(y_test, y_pred_proba_rf))

print("Random Forest Classification Report:\n", classification_report(y_test, y_pred_rf))


rf_accuracy = accuracy_score(y_test, y_pred_rf)
print("Random Forest Accuracy:", rf_accuracy)
# Out:
# Random Forest Accuracy: 0.6905263157894737
# Random Forest Precision: 0.6935847506575485
# Random Forest Recall: 0.6905263157894737
# Random Forest LogLoss: 2.9651404061786284
# Random Forest Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.72      0.67      0.69        42
#            1       0.50      0.33      0.40        42
#            2       0.68      0.86      0.76        35
#            3       0.57      0.83      0.68        29
#            4       0.60      0.90      0.72        39
#            5       0.84      0.82      0.83        45
#            6       0.86      0.82      0.84        44
#            7       0.67      0.67      0.67        36
#            8       0.67      0.76      0.71        34
#            9       0.43      0.65      0.52        31
#           10       0.76      0.66      0.70        47
#           11       0.71      0.69      0.70        35
#           12       0.75      0.86      0.80        42
#           13       0.44      0.40      0.42        40
#           14       0.56      0.50      0.53        36
#           15       0.71      0.77      0.74        35
#           16       0.83      0.67      0.74        43
#           17       0.56      0.57      0.57        47
#           18       0.70      0.84      0.77        37
#           19       0.53      0.46      0.49        37
#           20       0.78      0.91      0.84        44
#           21       0.51      0.46      0.49        41
#           22       0.63      0.47      0.54        40
#           23       0.71      0.83      0.76        35
#           24       0.41      0.26      0.32        46
#           25       0.71      0.69      0.70        36
#           26       0.73      1.00      0.84        37
#           27       0.74      0.58      0.65        45
#           28       0.85      0.81      0.83        36
#           29       0.73      0.74      0.74        47
#           30       0.79      0.72      0.75        46
#           31       0.65      0.76      0.70        37
#           32       0.58      0.50      0.54        38
#           33       0.66      0.89      0.76        37
#           34       0.54      0.49      0.51        41
#           35       0.76      0.84      0.80        38
#           36       0.76      0.71      0.74        35
#           37       0.67      0.58      0.63        53
#           38       0.69      0.62      0.65        53
#           39       0.81      0.74      0.77        46
#           40       0.71      0.71      0.71        51
#           41       0.79      0.79      0.79        43
#           42       0.63      0.44      0.52        39
#           43       0.80      0.80      0.80        41
#           44       0.96      0.98      0.97        44
#           45       0.49      0.51      0.50        35
#           46       0.73      0.63      0.68        35
#           47       0.63      0.49      0.55        39
#           48       0.69      0.78      0.73        37
#           49       0.76      0.74      0.75        43
#           50       0.58      0.66      0.62        32
#           51       0.48      0.53      0.50        38
#           52       0.79      0.69      0.74        49
#           53       0.56      0.77      0.65        31
#           54       0.80      0.74      0.77        47
#           55       0.51      0.63      0.57        41
#           56       0.91      0.91      0.91        47
#           57       0.71      0.69      0.70        36
#           58       0.78      0.83      0.81        35
#           59       0.69      0.79      0.74        39
#           60       0.76      0.88      0.81        40
#           61       0.74      0.57      0.65        56
#           62       0.85      0.70      0.77        57
#           63       0.55      0.59      0.57        27
#           64       0.69      0.74      0.72        39
#           65       0.65      0.69      0.67        35
#           66       0.60      0.78      0.68        46
#           67       0.70      0.86      0.77        37
#           68       0.79      0.56      0.66        48
#           69       0.51      0.42      0.46        43
#           70       0.89      0.91      0.90        34
#           71       0.72      0.81      0.76        36
#           72       0.74      0.67      0.70        39
#           73       0.93      0.90      0.91        41
#           74       0.65      0.49      0.56        53
#           75       0.85      0.92      0.88        37
#           76       0.93      0.93      0.93        44
#           77       0.59      0.43      0.50        30
#           78       0.51      0.50      0.51        36
#           79       0.39      0.50      0.44        30
#           80       0.78      0.80      0.79        40
#           81       0.60      0.60      0.60        45
#           82       0.83      0.53      0.65        45
#           83       0.58      0.71      0.64        31
#           84       0.55      0.70      0.62        40
#           85       0.88      0.80      0.83        44
#           86       0.95      0.95      0.95        37
#           87       0.69      0.71      0.70        35
#           88       0.65      0.65      0.65        37
#           89       0.59      0.61      0.60        38
#           90       0.67      0.56      0.61        36
#           91       0.69      0.69      0.69        39
#           92       0.68      0.66      0.67        35
#           93       0.78      0.90      0.83        39
#           94       0.53      0.60      0.56        42
#
#     accuracy                           0.69      3800
#    macro avg       0.69      0.69      0.68      3800
# weighted avg       0.69      0.69      0.69      3800
#
# Random Forest Accuracy: 0.6905263157894737

# %%
cm = confusion_matrix(y_test,  y_pred_rf)
print(cm)
# Out:
# [[28  0  0 ...  0  0  0]
#  [ 0 14  5 ...  0  0  0]
#  [ 0  0 30 ...  1  0  0]
#  ...
#  [ 0  0  1 ... 23  0  1]
#  [ 0  0  0 ...  0 35  0]
#  [ 0  0  0 ...  0  0 25]]
